# %%
# Dictionary to represent object

person = {'name': 'Alan Santos', 
'city': 'Niteroi',
'age': '100',
'hobbies': ['music', 'guitar']}

print(person.get('name'), 'is', person.get('age'), 'years old')
# Out:
# Alan Santos is 100 years old
